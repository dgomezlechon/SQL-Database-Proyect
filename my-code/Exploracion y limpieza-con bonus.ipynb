# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
import warnings
warnings.simplefilter('ignore')

# para pintar
import pylab as plt
import seaborn as sns
import numpy as np

# para que salga el grafico
# %matplotlib inline

# %% [markdown]
# ## Carga de los datos

# %%
actor_csv=pd.read_csv("../data/actor.csv")
category_csv=pd.read_csv("../data/category.csv")
film_csv=pd.read_csv("../data/film.csv")
inventory_csv=pd.read_csv("../data/inventory.csv")
language_csv=pd.read_csv("../data/language.csv")
rental_csv=pd.read_csv("../data/rental.csv")
old_hdd_csv=pd.read_csv("../data/old_HDD.csv")

# %% [markdown]
# ## Exploración de los datos

# %% [markdown]
# Exploramos actor_csv

# %%
actor_csv.head(2)
# Out:
#    actor_id first_name last_name          last_update
# 0         1   PENELOPE   GUINESS  2006-02-15 04:34:33
# 1         2       NICK  WAHLBERG  2006-02-15 04:34:33

# %%
actor_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   actor_id     200 non-null    int64
#  1   first_name   200 non-null    object
#  2   last_name    200 non-null    object
#  3   last_update  200 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 6.4+ KB

# %% [markdown]
# Exploramos category_csv:

# %%
category_csv.head(1)
# Out:
#    category_id    name          last_update
# 0            1  Action  2006-02-15 04:46:27

# %%
category_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   category_id  16 non-null     int64
#  1   name         16 non-null     object
#  2   last_update  16 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 512.0+ bytes

# %% [markdown]
# Exploramos film_csv:

# %%
film_csv.head(2)
# Out:
#    film_id             title  \
# 0        1  ACADEMY DINOSAUR
# 1        2    ACE GOLDFINGER
#
#                                          description  release_year  \
# 0  A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1  A Astounding Epistle of a Database Administrat...          2006
#
#    language_id  original_language_id  rental_duration  rental_rate  length  \
# 0            1                   NaN                6         0.99      86
# 1            1                   NaN                3         4.99      48
#
#    replacement_cost rating                  special_features  \
# 0             20.99     PG  Deleted Scenes,Behind the Scenes
# 1             12.99      G           Trailers,Deleted Scenes
#
#            last_update
# 0  2006-02-15 05:03:42
# 1  2006-02-15 05:03:42

# %%
film_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   film_id               1000 non-null   int64
#  1   title                 1000 non-null   object
#  2   description           1000 non-null   object
#  3   release_year          1000 non-null   int64
#  4   language_id           1000 non-null   int64
#  5   original_language_id  0 non-null      float64
#  6   rental_duration       1000 non-null   int64
#  7   rental_rate           1000 non-null   float64
#  8   length                1000 non-null   int64
#  9   replacement_cost      1000 non-null   float64
#  10  rating                1000 non-null   object
#  11  special_features      1000 non-null   object
#  12  last_update           1000 non-null   object
# dtypes: float64(3), int64(5), object(5)
# memory usage: 101.7+ KB

# %% [markdown]
# Exploramos inventory_csv:

# %%
inventory_csv.head(2)
# Out:
#    inventory_id  film_id  store_id          last_update
# 0             1        1         1  2006-02-15 05:09:17
# 1             2        1         1  2006-02-15 05:09:17

# %%
inventory_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   inventory_id  1000 non-null   int64
#  1   film_id       1000 non-null   int64
#  2   store_id      1000 non-null   int64
#  3   last_update   1000 non-null   object
# dtypes: int64(3), object(1)
# memory usage: 31.4+ KB

# %% [markdown]
# Exploramos language_csv:

# %%
language_csv.head(2)
# Out:
#    language_id     name          last_update
# 0            1  English  2006-02-15 05:02:19
# 1            2  Italian  2006-02-15 05:02:19

# %%
language_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   language_id  6 non-null      int64
#  1   name         6 non-null      object
#  2   last_update  6 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 272.0+ bytes

# %% [markdown]
# Exploramos rental_csv:

# %%
rental_csv.head(2)
# Out:
#    rental_id          rental_date  inventory_id  customer_id  \
# 0          1  2005-05-24 22:53:30           367          130
# 1          2  2005-05-24 22:54:33          1525          459
#
#            return_date  staff_id          last_update
# 0  2005-05-26 22:04:30         1  2006-02-15 21:30:53
# 1  2005-05-28 19:40:33         1  2006-02-15 21:30:53

# %%
rental_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   rental_id     1000 non-null   int64
#  1   rental_date   1000 non-null   object
#  2   inventory_id  1000 non-null   int64
#  3   customer_id   1000 non-null   int64
#  4   return_date   1000 non-null   object
#  5   staff_id      1000 non-null   int64
#  6   last_update   1000 non-null   object
# dtypes: int64(4), object(3)
# memory usage: 54.8+ KB

# %% [markdown]
# Exploramos old_hdd_csv:

# %%
old_hdd_csv.head(1)
# Out:
#   first_name last_name             title  release_year  category_id
# 0   PENELOPE   GUINESS  ACADEMY DINOSAUR          2006            6

# %%
old_hdd_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   first_name    1000 non-null   object
#  1   last_name     1000 non-null   object
#  2   title         1000 non-null   object
#  3   release_year  1000 non-null   int64
#  4   category_id   1000 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 39.2+ KB

# %% [markdown]
# Después de explorar las tablas vemos que es un negocio de alquiler de películas.
#
# Por un lado tenemos la tabla rental_csv que es como si fueran los invoices, es decir para cada película que se alquila tenemos la información sobre esa operación. Esta tabla se relaciona por un lado a inventory_csv por el inventory_id ya que tenemos que saber que cinta particular de nuestro stock se ha alquilado. De la misma manera, el inventory_csv esta unido a film_csv por el film_id ya que tenemos que saber a que título de película corresponde la cinta que estamos alquilando.
#
#
# También tenemos relación entrar film_csv y language_csv >> están relacionadas por el language_id ya que tenemos que saber en que lenguaje está la película.
#
# Finalmente tenemos otra tabla llamada old_hdd_csv que une por un lado con la tabla category_csv a través del category_id, por otro lado con la tabla film_csv a través de title y con actor_csv a través de name y first_name.
#
# #### Entre film_csv y actor_csv habrá una relación many to many y entre category_id y film_id habrá una relación one to one

# %% [markdown]
# # Limpieza de Datos

# %% [markdown]
# Hemos visto que solo hay nulos en el film_csv en la columna original_language_id que es toda nula, por lo que vamos a eliminar la columna directamente

# %%
film_csv.drop('original_language_id', axis=1, inplace=True)

# %%
film_csv.head(1)
# Out:
#    film_id             title  \
# 0        1  ACADEMY DINOSAUR
#
#                                          description  release_year  \
# 0  A Epic Drama of a Feminist And a Mad Scientist...          2006
#
#    language_id  rental_duration  rental_rate  length  replacement_cost rating  \
# 0            1                6         0.99      86             20.99     PG
#
#                    special_features          last_update
# 0  Deleted Scenes,Behind the Scenes  2006-02-15 05:03:42

# %% [markdown]
# Vamos a eliminar los duplicados

# %%
actor_csv.duplicated().any()
# Out:
# False

# %%
category_csv.duplicated().any()
# Out:
# False

# %%
film_csv.duplicated().any()
# Out:
# False

# %%
inventory_csv.duplicated().any()
# Out:
# False

# %%
language_csv.duplicated().any()
# Out:
# False

# %%
rental_csv.duplicated().any()
# Out:
# False

# %%
old_hdd_csv.duplicated().any()
# Out:
# False

# %% [markdown]
# No hay duplicados en ningún csv por lo que ya están limpios los datos

# %% [markdown]
# Las columnas last_update entiendo que hacen referencia a la última vez que se actualizó la base de datos por lo que no me van a ofrecer información relevante, así que las elimino.

# %%
actor_csv.drop('last_update', axis=1, inplace=True)
category_csv.drop('last_update', axis=1, inplace=True)
film_csv.drop('last_update', axis=1, inplace=True)
inventory_csv.drop('last_update', axis=1, inplace=True)
language_csv.drop('last_update', axis=1, inplace=True)
rental_csv.drop('last_update', axis=1, inplace=True)

# %% [markdown]
# ## Unimos first_name y last_name en actor_csv y old_hdd_csv

# %%
actor_csv["full name"]=actor_csv.first_name+" "+actor_csv.last_name

# %%
film_csv.tail()
# Out:
#      film_id              title  \
# 995      996     YOUNG LANGUAGE
# 996      997         YOUTH KICK
# 997      998       ZHIVAGO CORE
# 998      999  ZOOLANDER FICTION
# 999     1000          ZORRO ARK
#
#                                            description  release_year  \
# 995  A Unbelieveable Yarn of a Boat And a Database ...          2006
# 996  A Touching Drama of a Teacher And a Cat who mu...          2006
# 997  A Fateful Yarn of a Composer And a Man who mus...          2006
# 998  A Fateful Reflection of a Waitress And a Boat ...          2006
# 999  A Intrepid Panorama of a Mad Scientist And a B...          2006
#
#      language_id  rental_duration  rental_rate  length  replacement_cost  \
# 995            1                6         0.99     183              9.99
# 996            1                4         0.99     179             14.99
# 997            1                6         0.99     105             10.99
# 998            1                5         2.99     101             28.99
# 999            1                3         4.99      50             18.99
#
#     rating                         special_features
# 995      G               Trailers,Behind the Scenes
# 996  NC-17               Trailers,Behind the Scenes
# 997  NC-17                           Deleted Scenes
# 998      R                  Trailers,Deleted Scenes
# 999  NC-17  Trailers,Commentaries,Behind the Scenes

# %%
actor_csv.head(1)
# Out:
#    actor_id first_name last_name         full name
# 0         1   PENELOPE   GUINESS  PENELOPE GUINESS

# %%
old_hdd_csv["full name"]=old_hdd_csv.first_name+" "+old_hdd_csv.last_name

# %% [markdown]
# Vamos a elimnar columnas first name y last_name

# %%
old_hdd_csv.drop('first_name', axis=1, inplace=True)

# %%
old_hdd_csv.drop('last_name', axis=1, inplace=True)

# %%
old_hdd_csv.head(1)
# Out:
#               title  release_year  category_id         full name
# 0  ACADEMY DINOSAUR          2006            6  PENELOPE GUINESS

# %% [markdown]
# ## Unión film_csv y old_hdd_csv

# %% [markdown]
# Estas dos columnas están relacionadas for "title". El problema es que si comparamos, en old_hdd_csv no están incluidos todos los títulos de film_csv

# %%
film_csv.title.isin(old_hdd_csv.title).unique()
# Out:
# array([ True, False])

# %%
old_hdd_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         1000 non-null   object
#  1   release_year  1000 non-null   int64
#  2   category_id   1000 non-null   int64
#  3   full name     1000 non-null   object
# dtypes: int64(2), object(2)
# memory usage: 31.4+ KB

# %%
frame_to_join=pd.DataFrame()

# %%
frame_to_join['title']=film_csv.title[~film_csv['title'].isin(old_hdd_csv.title)]

# %%
frame_to_join['release_year']=film_csv.release_year[~film_csv['release_year'].isin(old_hdd_csv.title)]

# %% [markdown]
# El full_name del actor no lo sabemos para las películas que no están incluidas en old_hdd_csv por lo uqe rellenamos con unknown

# %%
frame_to_join['full name']="Unknown"

# %% [markdown]
# nos falta añadir el category_id de las peliculas que faltan, no tenemos la información por lo que vamos a ponerle categoria 0

# %%
frame_to_join['category_id']=0

# %%
frame_to_join.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 386 entries, 3 to 999
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         386 non-null    object
#  1   release_year  386 non-null    int64
#  2   full name     386 non-null    object
#  3   category_id   386 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 15.1+ KB

# %% [markdown]
# Ahora vamos a unir las Dataframes old_hdd_csv y frame_to_join

# %%
old_hdd_csv=pd.concat([old_hdd_csv,frame_to_join])

# %%
old_hdd_csv.head(2)
# Out:
#                   title  release_year  category_id         full name
# 0      ACADEMY DINOSAUR          2006            6  PENELOPE GUINESS
# 1  ANACONDA CONFESSIONS          2006            2  PENELOPE GUINESS

# %% [markdown]
# ## Añadiendo categoria

# %% [markdown]
# Vamos a añadir una nueva categoria a category_id que sea categoria 0 == "Unknown" para que no nos den problema aquellas peliculas para las que no tenemos categorias

# %%
data=[{"category_id":0,"name":"unknown"}]

# %%
category_csv=category_csv.append(data,ignore_index=True,sort=False)

# %% [markdown]
# ## Editamos el inventory_id

# %% [markdown]
# Como el inventory_id en la tabla inventory va solo del 1-1000 y  en la tabla rental tenemos una gran parte de inventories superiores a 1000, no podriamos trabajar con los inventory ids con la mayoria de películas. Entonces para poder trabajar bien, vamos a sustituir los valores de la columna inventory_id de la dataframe rental_csv por valores random entre el 1-1000.

# %%
rental_csv.inventory_id=np.random.randint(1,1000, size=len(rental_csv))

# %% [markdown]
# # Subimos los csv

# %%
category_csv.to_csv("../data/clean2_csv/category_new.csv",index=False)

# %%
inventory_csv.to_csv("../data/clean2_csv/inventory_new.csv",index=False)

# %%
language_csv.to_csv("../data/clean2_csv/language_new.csv",index=False)

# %%
rental_csv.to_csv("../data/clean2_csv/rental_new.csv",index=False)

# %%
actor_csv.to_csv("../data/clean2_csv/actor.csv",index=False)

# %%
film_csv.to_csv("../data/clean2_csv/film.csv",index=False)

# %%
old_hdd_csv.to_csv("../data/clean2_csv/old_hdd.csv",index=False)

# %% [markdown]
# Exportamos la nueva tabla a csv

# %% [markdown]
# # BONUS

# %%
loc_clientes_csv=pd.read_csv("../data/clean2_csv/loc_clientes.csv")

# %%
loc_clientes_csv.head()
# Out:
#    customer_id  latitude  longitude shop_id
# 0          597  40.45724   -3.67688      S1
# 1          596  40.40381   -3.74130      S1
# 2          595  40.38840   -3.69511      S1
# 3          594  40.42183   -3.70529      S1
# 4          593  40.38975   -3.69018      S1

# %% [markdown]
# Importamos un csv con las coordenadas en las que fue la premiere de cada una de las películas. Vamos a plasmar en un mapa y ver si fuesemos un actor particular en que ciudad nos convendría vivir para estar más cerca de esas premieres

# %%
import re

# %%
import folium

# %%
def geomap(loc_clientes_csv, zoom_start=10.5):

    loc_clientes_csv.index=range(len(loc_clientes_csv)) 

    mapa=folium.Map(location=[40.463667, -3.74922],
                tiles='openstreetmap', zoom_start=zoom_start)

    for i in range(1, len(loc_clientes_csv)):

        folium.CircleMarker([float(loc_clientes_csv.latitude[i]), float(loc_clientes_csv.longitude[i])], popup=str(loc_clientes_csv.customer_id[i]), 
                             radius=1, icon=folium.Icon()).add_to(mapa)

    #mapa.save('images/geomap.html')
    
    
    return mapa

# %%
mapa=geomap(loc_clientes_csv.loc[:1500])
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_8f12d38fc8b447a5b91eb7583eb7fe09%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_8f12d38fc8b447a5b91eb7583eb7fe09%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_8f12d38fc8b447a5b91eb7583eb7fe09%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_8f12d38fc8b447a5b91eb7583eb7fe09%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.463667%2C%20-3.74922%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# primero hemos añadido un csv  con las loaclizaciones de nuestros clientes por customer_id. Ahora vamos a ver donde está localizada nuestra tienda en ese mapa. Para ello añadiremos una columna que sea shop_id a este csv y una columna con los datos por shop_id

# %%
shops_csv=pd.read_csv("../data/clean2_csv/shops.csv")

# %%
shops_csv
# Out:
#   shop_id  latitude  longitude
# 0      S2  40.45724  -3.676880
# 1      S1  40.40303  -3.692348

# %%
def geomap(shops_csv, zoom_start=11.5):

    shops_csv.index=range(len(shops_csv)) 

    mapa=folium.Map(location=[40.463667, -3.74922],
                tiles='openstreetmap', zoom_start=zoom_start)

    for i in range(1, len(shops_csv)):

        folium.Marker([float(shops_csv.latitude[i]), float(shops_csv.longitude[i])], popup=str(shops_csv.shop_id[i]), 
                             radius=1, icon=folium.Icon()).add_to(mapa)

    #mapa.save('images/geomap.html')
    
    
    return mapa

# %%
mapa=geomap(shops_csv.loc[:1500])
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_27502b63bf2b4f79b7129d29e22d9db8%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_27502b63bf2b4f79b7129d29e22d9db8%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_27502b63bf2b4f79b7129d29e22d9db8%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_27502b63bf2b4f79b7129d29e22d9db8%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.463667%2C%20-3.74922%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# ## Insertamos las nuevas tablas en SQL

# %% [markdown]
# Vamos a instertar las dos nuevas tablas en SQL utilizando SQL Alchemy

# %%
# %pip install SQLAlchemy
# Out:
# Requirement already satisfied: SQLAlchemy in /Users/danigomezlechonbarrachina/opt/anaconda3/envs/Ironhack/lib/python3.9/site-packages (1.4.35)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/danigomezlechonbarrachina/opt/anaconda3/envs/Ironhack/lib/python3.9/site-packages (from SQLAlchemy) (1.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pymysql
# Out:
# Requirement already satisfied: pymysql in /Users/danigomezlechonbarrachina/opt/anaconda3/envs/Ironhack/lib/python3.9/site-packages (1.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in /Users/danigomezlechonbarrachina/opt/anaconda3/envs/Ironhack/lib/python3.9/site-packages (8.0.28)
# Requirement already satisfied: protobuf>=3.0.0 in /Users/danigomezlechonbarrachina/opt/anaconda3/envs/Ironhack/lib/python3.9/site-packages (from mysql-connector-python) (3.20.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector as conn

# %%
from sqlalchemy import create_engine

# %%
# open a file
file = open("../password.txt")
  
# read the content of the file opened
content = file.readlines()
  
token=content[0]

# %%
str_conn=f'mysql+pymysql://root:'+token+'@127.0.0.1:3306'


motor=create_engine(str_conn)


motor.execute('use new_database2')

# %%
shops_csv.to_sql(name='shops', con=motor, if_exists='replace', index=False)

# %%
loc_clientes_csv.to_sql(name='loc_clientes', con=motor, if_exists='replace', index=False)

# %% [markdown]
# Creamos las relaciones de las nuevas tablas

# %%
motor.execute('alter table loc_clientes add primary key (customer_id)')

# %%
k='shops'
v='shop_id'
